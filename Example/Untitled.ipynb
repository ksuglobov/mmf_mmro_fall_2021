# %%
import requests as r

# %%
im = r.get("https://upload.wikimedia.org/wikipedia/ru/c/cb/Flyingcircus_2.jpg", stream = True)

# %%
im
# Out:
# <Response [200]>

# %%
from PIL import Image

# %%
Image.open(im.raw)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x300 at 0x11B4DC7BB38>

# %%
Image.open(im.raw).save("Monty.jpg")

# %% [markdown]
# # Title

# %% [markdown]
# <img src="Monty.jpg">

# %% [markdown]
# __[Monty](https://upload.wikimedia.org/wikipedia/ru/c/cb/Flyingcircus_2.jpg)__

# %% [markdown]
# # $\frac{-b\pm\sqrt{b^2-4ac}}{2a}$

# %%
# %%time

for i in range(100000):
    pass
# Out:
# Wall time: 8.96 ms
